# %%
# Package imports
import numpy as np
from sklearn.model_selection import train_test_split

# Matplotlib is a matlab like plotting library
import matplotlib
from matplotlib import pyplot as plt
# SciKitLearn is a useful machine learning utilities library
import sklearn
# The sklearn dataset module helps generating |datasets
import sklearn.datasets
import sklearn.linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import normalize
from scipy.stats import gaussian_kde

# %%
# importing dataset
# import data
from DataExtraction import dataNoMass as data
from DataExtraction import dataWithP2
from DataExtraction import dataWithP2E2 
from DataExtraction import dataWithMass 
#from DataExtraction import p2E2 as data
from DataExtraction import e2P2Dec 
#from DataExtraction import labels
from DataExtraction import labels2D as labels
data = np.array(data)
labels = np.array(labels)

# %%
# split data 
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, train_size=0.5, test_size=0.5, random_state=42)

# %%
for i in range(5):
    print(train_data[i])

# remove phi from dataset
train_data = np.delete(train_data, 2, 1)
# Out:
# [28.73596191  0.8398658  -0.11143488 39.48083318]
# [47.30611801  1.31948066 -0.59230787 94.81924115]
# [151.81565857   0.9477132   -0.26961038 225.25115398]
# [335.43484497  -0.39157015   0.69631833 361.48074898]
# [32.45707321 -0.29633594  2.52936745 33.89280616]

# %%
#Normalize train data
train_data[:,0] = train_data[:,0] / np.linalg.norm(train_data[:,0]) # normalize column 0
train_data[:,1] = train_data[:,1] / np.linalg.norm(train_data[:,1]) # normalize column 1
train_data[:,2] = train_data[:,2] / np.linalg.norm(train_data[:,2]) # normalize column 2
# train_data[:,2] = train_data[:,3] / np.linalg.norm(train_data[:,3]) # normalize column 3
#Normalize test data
test_data[:,0] = test_data[:,0] / np.linalg.norm(test_data[:,0]) # normalize column 0
test_data[:,1] = test_data[:,1] / np.linalg.norm(test_data[:,1]) # normalize column 1
test_data[:,2] = test_data[:,2] / np.linalg.norm(test_data[:,2]) # normalize column 2
# test_data[:,2] = test_data[:,3] / np.linalg.norm(test_data[:,3]) # normalize column 3


for i in range(5):
    print(train_data[i])
# Out:
# [1.16644512e-04 3.68381017e-03 8.88321225e-05]
# [0.00019202 0.00578749 0.00021334]
# [0.00061625 0.00415685 0.00050682]
# [ 0.00136159 -0.0017175   0.00081333]
# [ 1.31749181e-04 -1.29978543e-03  7.62590266e-05]

# %%
#old data normalization
# train_data = train_data/avgE2
# test_data = test_data/avgE2
# X = train_data
# test_data
# for i in range(5): 
#     print(train_data[i])
# print("bruh")
# for i in range(5): 
#     print(test_data[i])
# print(X.shape)

# %%
# take first two columns of data
# train_data = train_data[:,0:2]
# test_data = test_data[:,0:2]
# train_labels = train_labels[0:9]
for i in range(5):
    print(train_data[i])
for i in range(5):
    print(test_data[i])
# Out:
# [ 1.16644512e-04  3.68381017e-03 -3.08543208e-04  8.88321225e-05]
# [ 0.00019202  0.00578749 -0.00163999  0.00021334]
# [ 0.00061625  0.00415685 -0.0007465   0.00050682]
# [ 0.00136159 -0.0017175   0.00192798  0.00081333]
# [ 1.31749181e-04 -1.29978543e-03  7.00336480e-03  7.62590266e-05]
# [ 0.00031031  0.00759723 -0.00505055  0.00041595]
# [ 0.00029495 -0.0034448  -0.00836765  0.00017956]
# [ 0.00127943 -0.00695786 -0.00485524  0.00149743]
# [0.00053175 0.00303463 0.0036477  0.00030524]
# [ 0.00059107  0.00370992 -0.00591427  0.00037477]

# %%
# Now we define all our functions

def softmax(z):
    #Calculate exponent term first
    exp_scores = np.exp(z)
    return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

# loss functions
def softmax_loss(y,y_hat):
    # Clipping value
    minval = 0.000000000001
    # Number of samples
    m = y.shape[0]
    # Loss formula, note that np.sum sums up the entire matrix and therefore does the job of two sums from the formula
    loss = -1/m * np.sum(y * np.log(y_hat.clip(min=minval)))
    #loss = -1/m * np.sum(y * np.log(y_hat))
    return loss

def crossEntropy_loss(y, y_hat):
    m = y.shape[0]
    if y.all() == 1:
        return -1/m * np.sum(np.log(y_hat))
    else:
        return -1/m * np.sum(np.log(1 - y_hat))

def mse_loss(y, y_hat):
    m = y.shape[0]
    return np.sum((y_hat - y)**2) / m
    
def loss_derivative(y,y_hat):
    return (y_hat-y)

def tanh_derivative(x):
    return (1 - np.power(x, 2))

# This is the forward propagation function
def forward_prop(model,a0):
    
    #Start Forward Propagation
    
    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'],model['b3']
    
    # Do the first Linear step 
    # Z1 is the input layer x times the dot product of the weights + our bias b
    z1 = a0.dot(W1) + b1
    
    # Put it through the first activation function
    a1 = np.tanh(z1)
    
    # Second linear step
    z2 = a1.dot(W2) + b2
    
    # Second activation function
    a2 = np.tanh(z2)
    
    #Third linear step
    z3 = a2.dot(W3) + b3
    
    #For the Third linear activation function we use the softmax function, either the sigmoid of softmax should be used for the last layer
    a3 = softmax(z3)
    
    #Store all results in these values
    cache = {'a0':a0,'z1':z1,'a1':a1,'z2':z2,'a2':a2,'a3':a3,'z3':z3}
    return cache

# This is the BACKWARD PROPAGATION function
def backward_prop(model,cache,y):

    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'],model['W3'],model['b3']
    # Load forward propagation results
    a0,a1, a2,a3 = cache['a0'],cache['a1'],cache['a2'],cache['a3']
    
    # Get number of samples
    m = y.shape[0]
    
    # Calculate loss derivative with respect to output
    dz3 = loss_derivative(y=y,y_hat=a3)

    # Calculate loss derivative with respect to second layer weights
    dW3 = 1/m*(a2.T).dot(dz3) #dW2 = 1/m*(a1.T).dot(dz2) 
    
    # Calculate loss derivative with respect to second layer bias
    db3 = 1/m*np.sum(dz3, axis=0)
    
    # Calculate loss derivative with respect to first layer
    dz2 = np.multiply(dz3.dot(W3.T) ,tanh_derivative(a2))
    
    # Calculate loss derivative with respect to first layer weights
    dW2 = 1/m*np.dot(a1.T, dz2)
    
    # Calculate loss derivative with respect to first layer bias
    db2 = 1/m*np.sum(dz2, axis=0)
    
    dz1 = np.multiply(dz2.dot(W2.T),tanh_derivative(a1))
    
    dW1 = 1/m*np.dot(a0.T,dz1)
    
    db1 = 1/m*np.sum(dz1,axis=0)
    
    # Store gradients
    grads = {'dW3':dW3, 'db3':db3, 'dW2':dW2,'db2':db2,'dW1':dW1,'db1':db1}
    return grads

#TRAINING PHASE
def initialize_parameters(nn_input_dim,nn_hdim,nn_output_dim):
    # First layer weights
    W1 = 2 *np.random.randn(nn_input_dim, nn_hdim) - 1
    
    # First layer bias
    b1 = np.zeros((1, nn_hdim))
    
    # Second layer weights
    W2 = 2 * np.random.randn(nn_hdim, nn_hdim) - 1
    
    # Second layer bias
    b2 = np.zeros((1, nn_hdim))
    W3 = 2 * np.random.rand(nn_hdim, nn_output_dim) - 1
    b3 = np.zeros((1,nn_output_dim))
    
    
    # Package and return model
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2,'W3':W3,'b3':b3}
    return model

def update_parameters(model,grads,learning_rate):
    # Load parameters
    W1, b1, W2, b2,b3,W3 = model['W1'], model['b1'], model['W2'], model['b2'],model['b3'],model["W3"]
    
    # Update parameters
    W1 -= learning_rate * grads['dW1']
    b1 -= learning_rate * grads['db1']
    W2 -= learning_rate * grads['dW2']
    b2 -= learning_rate * grads['db2']
    W3 -= learning_rate * grads['dW3']
    b3 -= learning_rate * grads['db3']
    
    # Store and return parameters
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3':W3,'b3':b3}
    return model
def predict(model, x):
    # Do forward pass
    c = forward_prop(model,x)
    #get y_hat
    y_hat = c['a3']
    # plotArr.append([x, y_hat]) #added to make plot
    return y_hat
def calc_accuracy(model,x,y):
    # Get total number of examples
    m = y.shape[0]
    # Do a prediction with the model
    pred = predict(model,x)
    # Ensure prediction and truth vector y have the same shape
    pred = pred.reshape(y.shape)
    # Calculate the number of wrong examples
    error = np.sum(np.abs(pred-y))
    # Calculate accuracy
    return (m - error)/m * 100
def train(model,X_,y_,learning_rate, epochs=2001, print_loss=False):
    # Gradient descent. Loop over epochs
    for i in range(0, epochs):

        # Forward propagation
        cache = forward_prop(model,X_)
        #a1, probs = cache['a1'],cache['a2']
        # Backpropagation
        
        grads = backward_prop(model,cache,y_)
        # Gradient descent parameter update
        # Assign new parameters to the model
        model = update_parameters(model=model,grads=grads,learning_rate=learning_rate)
    
        a3 = cache['a3']
        thisLoss = mse_loss(y_,a3) # set loss function here
        losses.append(thisLoss)
        y_hat = predict(model,X_) # getting rid of this because it's wrong
        y_true = y_.argmax(axis=1)
        accur = accuracy_score(a3,train_labels)
        train_accuracies.append(accur)
        
        if i % 50 == 0:
            placeholderVar = accuracy_score(a3, train_labels)
            test_accuracy = accuracyOfModel(model, test_data, test_labels)
            test_accuracies.append(test_accuracy)
            test_num.append(i)
        #Printing loss & accuracy every 100 iterations
        if print_loss and i % 300==0:
            print('Loss after iteration',i,':',thisLoss)
            print('Train Accuracy after iteration',i,':',accur*100,'%')
            print('Test Accuracy after iteration',i,':',test_accuracy*100,'%')
    return model

# TESTING PHASE
# test the accuracy of any model
def accuracyOfModel(_model, _testData, _testLabels):
    y_pred = predict(_model,_testData) # make predictions on test data
    y_true = _testLabels # get usable info from labels
    return accuracy_score(y_pred, y_true)

def accuracy_score(_outputNodes, _labels):
    for i in range(len(_outputNodes)-1):
        if _outputNodes[i][0]>.5:
            _outputNodes[i]=[1,0]
        else:
            _outputNodes[i]=[0,1]
    numWrong = np.count_nonzero(np.subtract(_outputNodes,_labels))/2
    return (len(_outputNodes)-numWrong)/len(_outputNodes)

# %%
# plotArr = []
losses = []
train_accuracies = []
test_accuracies = []
test_num = []
np.random.seed(0)
# This is what we return at the end
model = initialize_parameters(nn_input_dim=4, nn_hdim= 7, nn_output_dim= 2)
model = train(model,train_data,train_labels,learning_rate=0.01,epochs=14001,print_loss=True)
# Out:
# Loss after iteration 0 : 0.5023226841946036
# Train Accuracy after iteration 0 : 50.13021162549619 %
# Test Accuracy after iteration 0 : 49.48800283178681 %
# Loss after iteration 300 : 0.5021950462363546
# Train Accuracy after iteration 300 : 50.19342115243609 %
# Test Accuracy after iteration 300 : 49.51075826148517 %
# Loss after iteration 600 : 0.50208558989401
# Train Accuracy after iteration 600 : 50.07964400394428 %
# Test Accuracy after iteration 600 : 49.57649616950267 %
# Loss after iteration 900 : 0.5019899128320727
# Train Accuracy after iteration 900 : 50.09987105256505 %
# Test Accuracy after iteration 900 : 49.54362721549392 %
# Loss after iteration 1200 : 0.5019049810409908
# Train Accuracy after iteration 1200 : 50.089757528254665 %
# Test Accuracy after iteration 1200 : 49.495587975019596 %
# Loss after iteration 1500 : 0.5018278000594087
# Train Accuracy after iteration 1500 : 50.17572248489293 %
# Test Accuracy after iteration 1500 : 49.470304164243636 %
# Loss after iteration 1800 : 0.501755178278372
# Train Accuracy after iteration 1800 : 50.125154863341 %
# Test Accuracy after iteration 1800 : 49.515815023640364 %
# Loss after iteration 2100 : 0.5016836497791717
# Train Accuracy after iteration 2100 : 50.13526838765139 %
# Test Accuracy after iteration 2100 : 49.57396778842507 %
# Loss after iteration 2400 : 0.5016098773675328
# Train Accuracy after iteration 2400 : 50.15802381734975 %
# Test Accuracy after iteration 2400 : 49.57396778842507 %
# Loss after iteration 2700 : 0.5015318754278691
# Train Accuracy after iteration 2700 : 50.20606305782408 %
# Test Accuracy after iteration 2700 : 49.546155596571516 %
# Loss after iteration 3000 : 0.5014506604853775
# Train Accuracy after iteration 3000 : 50.1883643902809 %
# Test Accuracy after iteration 3000 : 49.541098834416324 %
# Loss after iteration 3300 : 0.5013705789932854
# Train Accuracy after iteration 3300 : 50.15043867411696 %
# Test Accuracy after iteration 3300 : 49.58913807489065 %
# Loss after iteration 3600 : 0.5012970136542795
# Train Accuracy after iteration 3600 : 50.084700766099466 %
# Test Accuracy after iteration 3600 : 49.57396778842507 %
# Loss after iteration 3900 : 0.5012333266887037
# Train Accuracy after iteration 3900 : 50.104927814720234 %
# Test Accuracy after iteration 3900 : 49.62706379105459 %
# Loss after iteration 4200 : 0.5011798700432074
# Train Accuracy after iteration 4200 : 50.14285353088418 %
# Test Accuracy after iteration 4200 : 49.66498950721853 %
# Loss after iteration 4500 : 0.5011350523904066
# Train Accuracy after iteration 4500 : 50.17319410381532 %
# Test Accuracy after iteration 4500 : 49.680159793684105 %
# Loss after iteration 4800 : 0.50109673937471
# Train Accuracy after iteration 4800 : 50.10998457687542 %
# Test Accuracy after iteration 4800 : 49.73325579631362 %
# Loss after iteration 5100 : 0.5010630514210859
# Train Accuracy after iteration 5100 : 50.117569720108214 %
# Test Accuracy after iteration 5100 : 49.692801699072085 %
# Loss after iteration 5400 : 0.5010325980820436
# Train Accuracy after iteration 5400 : 50.10998457687542 %
# Test Accuracy after iteration 5400 : 49.71302874769285 %
# Loss after iteration 5700 : 0.5010044392979195
# Train Accuracy after iteration 5700 : 50.09481429040985 %
# Test Accuracy after iteration 5700 : 49.71050036661526 %
# Loss after iteration 6000 : 0.5009779701069482
# Train Accuracy after iteration 6000 : 50.10239943364264 %
# Test Accuracy after iteration 6000 : 49.705443604460065 %
# Loss after iteration 6300 : 0.5009528112947523
# Train Accuracy after iteration 6300 : 50.07711562286667 %
# Test Accuracy after iteration 6300 : 49.67257465045132 %
# Loss after iteration 6600 : 0.5009287277160571
# Train Accuracy after iteration 6600 : 50.089757528254665 %
# Test Accuracy after iteration 6600 : 49.65993274506334 %
# Loss after iteration 6900 : 0.5009055731994724
# Train Accuracy after iteration 6900 : 50.089757528254665 %
# Test Accuracy after iteration 6900 : 49.654875982908145 %
# Loss after iteration 7200 : 0.500883255277489
# Train Accuracy after iteration 7200 : 50.11504133903062 %
# Test Accuracy after iteration 7200 : 49.65740436398574 %
# Loss after iteration 7500 : 0.5008617132579252
# Train Accuracy after iteration 7500 : 50.09481429040985 %
# Test Accuracy after iteration 7500 : 49.66246112614093 %
# Loss after iteration 7800 : 0.5008409048278915
# Train Accuracy after iteration 7800 : 50.054360193168314 %
# Test Accuracy after iteration 7800 : 49.629592172132185 %
# Loss after iteration 8100 : 0.5008207979716055
# Train Accuracy after iteration 8100 : 50.08722914717706 %
# Test Accuracy after iteration 8100 : 49.61442188566661 %
# Loss after iteration 8400 : 0.5008013661546704
# Train Accuracy after iteration 8400 : 50.036661525625135 %
# Test Accuracy after iteration 8400 : 49.66498950721853 %
# Loss after iteration 8700 : 0.5007825855065495
# Train Accuracy after iteration 8700 : 50.054360193168314 %
# Test Accuracy after iteration 8700 : 49.66246112614093 %
# Loss after iteration 9000 : 0.5007644332249959
# Train Accuracy after iteration 9000 : 50.0568885742459 %
# Test Accuracy after iteration 9000 : 49.66246112614093 %
# Loss after iteration 9300 : 0.5007468867281233
# Train Accuracy after iteration 9300 : 50.0568885742459 %
# Test Accuracy after iteration 9300 : 49.70291522338247 %
# Loss after iteration 9600 : 0.500729923262411
# Train Accuracy after iteration 9600 : 50.10998457687542 %
# Test Accuracy after iteration 9600 : 49.680159793684105 %
# Loss after iteration 9900 : 0.5007135197850188
# Train Accuracy after iteration 9900 : 50.09481429040985 %
# Test Accuracy after iteration 9900 : 49.67763141260651 %
# Loss after iteration 10200 : 0.5006976530056935
# Train Accuracy after iteration 10200 : 50.054360193168314 %
# Test Accuracy after iteration 10200 : 49.6826881747617 %
# Loss after iteration 10500 : 0.5006822995149424
# Train Accuracy after iteration 10500 : 50.07458724178908 %
# Test Accuracy after iteration 10500 : 49.67763141260651 %
# Loss after iteration 10800 : 0.5006674359514682
# Train Accuracy after iteration 10800 : 50.04677504993552 %
# Test Accuracy after iteration 10800 : 49.6852165558393 %
# Loss after iteration 11100 : 0.5006530391790507
# Train Accuracy after iteration 11100 : 50.0568885742459 %
# Test Accuracy after iteration 11100 : 49.64981922075295 %
# Loss after iteration 11400 : 0.5006390864546104
# Train Accuracy after iteration 11400 : 50.04677504993552 %
# Test Accuracy after iteration 11400 : 49.61442188566661 %
# Loss after iteration 11700 : 0.5006255555770153
# Train Accuracy after iteration 11700 : 50.05183181209072 %
# Test Accuracy after iteration 11700 : 49.58408131273546 %
# Loss after iteration 12000 : 0.5006124250115257
# Train Accuracy after iteration 12000 : 50.104927814720234 %
# Test Accuracy after iteration 12000 : 49.56891102626988 %
# Loss after iteration 12300 : 0.5005996739883124
# Train Accuracy after iteration 12300 : 50.10239943364264 %
# Test Accuracy after iteration 12300 : 49.53857045333873 %
# Loss after iteration 12600 : 0.5005872825757635
# Train Accuracy after iteration 12600 : 50.05183181209072 %
# Test Accuracy after iteration 12600 : 49.50317311825238 %
# Loss after iteration 12900 : 0.5005752317306519
# Train Accuracy after iteration 12900 : 50.04677504993552 %
# Test Accuracy after iteration 12900 : 49.50822988040757 %
# Loss after iteration 13200 : 0.5005635033279507
# Train Accuracy after iteration 13200 : 50.0568885742459 %
# Test Accuracy after iteration 13200 : 49.51834340471796 %
# Loss after iteration 13500 : 0.500552080173355
# Train Accuracy after iteration 13500 : 50.04930343101313 %
# Test Accuracy after iteration 13500 : 49.50570149932998 %
# Loss after iteration 13800 : 0.5005409460015461
# Train Accuracy after iteration 13800 : 50.054360193168314 %
# Test Accuracy after iteration 13800 : 49.50822988040757 %

# %%
plt.plot(losses, label="Loss")
plt.plot(train_accuracies, label="Train Accuracy")
plt.scatter(test_num, test_accuracies, label="Test Accuracy", s=16, color="green")
plt.legend()
plt.title("Network Loss and Accuracy per Epoch (Pt Eta Phi E)")
plt.xlabel("Epoch")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
for i in range (10):
    print(test_data[i])
print(len(test_data))
# Out:
# [ 0.00031031  0.00759723 -0.00505055  0.00041595]
# [ 0.00029495 -0.0034448  -0.00836765  0.00017956]
# [ 0.00127943 -0.00695786 -0.00485524  0.00149743]
# [0.00053175 0.00303463 0.0036477  0.00030524]
# [ 0.00059107  0.00370992 -0.00591427  0.00037477]
# [0.00033049 0.00065073 0.0060628  0.00015352]
# [ 0.00057019 -0.00297501 -0.00075887  0.00032466]
# [0.00071873 0.00406115 0.00653758 0.00048237]
# [0.00016823 0.0083256  0.00634707 0.00026398]
# [ 0.00128471 -0.00129253  0.0040473   0.00061612]
# 39551

# %%
# get weights and biases
W1, b1, W2, b2,b3,W3 = model['W1'], model['b1'], model['W2'], model['b2'],model['b3'],model["W3"]

diffArray = []

plotX = []
plotY = []

inputArr = []
outputArr = []
for i in range(len(test_data)-1):
    _a0 = test_data[i]
    #print(_a0, _a0[1]-_a0[0])
    diffArray.append(_a0[1]-_a0[0])
    inputArr.append(_a0[1])
    _z1 = _a0.dot(W1) + b1
    # Put it through the first activation function
    _a1 = np.tanh(_z1)
    # Second linear step
    _z2 = _a1.dot(W2) + b2
    # Second activation function
    _a2 = np.tanh(_z2)
    #Third linear step
    _z3 = _a2.dot(W3) + b3
    #For the Third linear activation function we use the softmax function, either the sigmoid of softmax should be used for the last layer
    _a3 = softmax(_z3)
#     if(i<10):
#         print(_a3)
    plotX.append(_a3[0][0])
    plotY.append(_a3[0][1])
plt.scatter(plotX, plotY)
    # Calculate the point density
#     xy = np.vstack([plotX,plotY])
#     z = gaussian_kde(xy)(xy)

#     fig, ax = plt.subplots()
#     ax.scatter(x, y, c=z, s=100, edgecolor='')
#     plt.show()

#plt.hist(diffArray, bins=500)
# Out:
# [[0.55845105 0.44154895]]
# [[0.47302866 0.52697134]]
# [[0.44130053 0.55869947]]
# [[0.52119024 0.47880976]]
# [[0.52646688 0.47353312]]
# [[0.50388674 0.49611326]]
# [[0.47449857 0.52550143]]
# [[0.52789532 0.47210468]]
# [[0.56409413 0.43590587]]
# [[0.48233353 0.51766647]]

# %%
# plot muons, this doesn't work right now and we have no idea why
muonX = [] # value of "muon" output node
muonY = [] # value of "electron" output node
mCount = 0
for x, y, l in zip(plotX, plotY, test_labels):
    if l[0]==1:
        mCount +=1
        if(np.isnan(x) or np.isnan(y) or np.isinf(x) or np.isinf(y)or x<0 or y<0)!=True:
            muonX.append(x)
            muonY.append(y)
print(mCount-len(muonX), "lost muons")
# Calculate the point density
muon_xy = np.vstack([muonX,muonY])
muon_z = gaussian_kde(muon_xy)(muon_xy)

fig, ax = plt.subplots()
ax.scatter(muonX, muonY, c=muon_z, s=100, edgecolor='')
plt.title("Electron Node Value vs Muon Node Value for True Muons")
plt.xlabel("Value of Muon Output Node")
plt.ylabel("Value of Electron Output Node")
plt.show()
#plt.scatter(muonX, muonY)
# Out:
# 0 lost muons
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-13-24994748d6a1> in <module>
#      12 # Calculate the point density
#      13 muon_xy = np.vstack([muonX,muonY])
# ---> 14 muon_z = gaussian_kde(muon_xy)(muon_xy)
#      15
#      16 fig, ax = plt.subplots()
#
# ~/LHCResearch/venv/lib/python3.6/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method)
#     170
#     171         self.d, self.n = self.dataset.shape
# --> 172         self.set_bandwidth(bw_method=bw_method)
#     173
#     174     def evaluate(self, points):
#
# ~/LHCResearch/venv/lib/python3.6/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     497             raise ValueError(msg)
#     498
# --> 499         self._compute_covariance()
#     500
#     501     def _compute_covariance(self):
#
# ~/LHCResearch/venv/lib/python3.6/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     508             self._data_covariance = atleast_2d(np.cov(self.dataset, rowvar=1,
#     509                                                bias=False))
# --> 510             self._data_inv_cov = linalg.inv(self._data_covariance)
#     511
#     512         self.covariance = self._data_covariance * self.factor**2
#
# ~/LHCResearch/venv/lib/python3.6/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     973         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     974     if info > 0:
# --> 975         raise LinAlgError("singular matrix")
#     976     if info < 0:
#     977         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix

# %%
# plot electrons
eleX = [] # value of "muon" output node
eleY = [] # value of "electron" output node
eCount = 0
for x, y, l in zip(plotX, plotY, test_labels):
    if l[0]==0:
        eCount +=1
        if(np.isnan(x) or np.isnan(y) or np.isinf(x) or np.isinf(y) or x<0 or y<0)!=True:
            eleX.append(x)
            eleY.append(y)
print(eCount-len(eleX), "lost electrons")
# Calculate the point density
ele_xy = np.vstack([eleX,eleY])
ele_z = gaussian_kde(ele_xy)(ele_xy)

fig, ax = plt.subplots()
ax.scatter(eleX, eleY, c=ele_z, s=100, edgecolor='')
plt.title("Electron Node Value vs Muon Node Value for True Electrons")
plt.xlabel("Value of Muon Output Node")
plt.ylabel("Value of Electron Output Node")
plt.show()

# %%
diffArr = []
discardedVals = 0
for x, y in zip(plotX, plotY):
    if(abs(y-x)<.75):
        diffArr.append(y-x)
    else:
        discardedVals += 1
print(discardedVals, "differences greater than .75")
plt.hist(diffArr, bins=1000)
plt.title("Difference in Electron and Muon Output Node Values (E-M)")

# %%
# make some models with different numbers of epochs
print("model 200")
model_200 = initialize_parameters(nn_input_dim=2, nn_hdim= 5, nn_output_dim= 2)
model_200 = train(model_200,train_data,train_labels,learning_rate=0.01,epochs=201,print_loss=True)
# model_300 = initialize_parameters(nn_input_dim=2, nn_hdim= 5, nn_output_dim= 2)
# model_300 = train(model_300,train_data,train_labels,learning_rate=0.01,epochs=301,print_loss=True)
print("model 400")
model_400 = initialize_parameters(nn_input_dim=2, nn_hdim= 5, nn_output_dim= 2)
model_400 = train(model_400,train_data,train_labels,learning_rate=0.01,epochs=401,print_loss=True)
# model_500 = initialize_parameters(nn_input_dim=2, nn_hdim= 5, nn_output_dim= 2)
# model_500 = train(model_500,train_data,train_labels,learning_rate=0.01,epochs=501,print_loss=True)

# %%
print("Model 200 accuracy: ", accuracyOfModel(model_200, test_data, test_labels))
print("Model 400 accuracy: ", accuracyOfModel(model_400, test_data, test_labels))
