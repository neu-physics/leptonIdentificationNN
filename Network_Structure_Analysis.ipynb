# %%
# Package imports
import numpy as np
from sklearn.model_selection import train_test_split

# Matplotlib is a matlab like plotting library
import matplotlib
from matplotlib import pyplot as plt
# SciKitLearn is a useful machine learning utilities library
import sklearn
# The sklearn dataset module helps generating |datasets
import sklearn.datasets
import sklearn.linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import normalize
from scipy.stats import gaussian_kde

# %%
# importing dataset
# import data
from DataExtraction import dataNoMass 
from DataExtraction import dataWithP2
from DataExtraction import dataWithP2E2 
from DataExtraction import dataWithMass 
from DataExtraction import p2E2 
from DataExtraction import e2P2Dec as data
from DataExtraction import labels2D as labels
#from DataExtraction import labels
data = np.array(data)
labels = np.array(labels)
# labels = np.row_stack(labels)

# %%
# split data 
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, train_size=0.5, test_size=0.5, random_state=42)

# %%
# normalize test data
# train_data[:,0] = train_data[:,0] / np.linalg.norm(train_data[:,0]) # normalize column 0
# train_data[:,1] = train_data[:,1] / np.linalg.norm(train_data[:,1]) # normalize column 1
#normalize train data
# test_data[:,0] = test_data[:,0] / np.linalg.norm(test_data[:,0]) # normalize column 0
# test_data[:,1] = test_data[:,1] / np.linalg.norm(test_data[:,1]) # normalize column 1

# %%
avgE2 = np.mean(train_data)

# %%
train_data = train_data/avgE2
test_data = test_data/avgE2

# %%
# messing with the number of training data points
# train_data = train_data[0:9]
# train_labels = train_labels[0:9]

# %%
# Now we define all our functions

def softmax(z):
    #Calculate exponent term first
    exp_scores = np.exp(z)
    return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

# loss functions
def softmax_loss(y,y_hat):
    # Clipping value
    minval = 0.000000000001
    # Number of samples
    m = y.shape[0]
    # Loss formula, note that np.sum sums up the entire matrix and therefore does the job of two sums from the formula
    loss = -1/m * np.sum(y * np.log(y_hat.clip(min=minval)))
    #loss = -1/m * np.sum(y * np.log(y_hat))
    return loss

def crossEntropy_loss(y, y_hat):
    m = y.shape[0]
    if y.all() == 1:
        return -1/m * np.sum(np.log(y_hat))
    else:
        return -1/m * np.sum(np.log(1 - y_hat))

def mse_loss(y, y_hat):
    m = y.shape[0]
    return np.sum((y_hat - y)**2) / m
    
def loss_derivative(y,y_hat):
    return (y_hat-y)

def tanh_derivative(x):
    return (1 - np.power(x, 2))

# This is the forward propagation function
def forward_prop(model,a0):
    
    #Start Forward Propagation
    
    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'],model['b3']
    
    # Do the first Linear step 
    # Z1 is the input layer x times the dot product of the weights + our bias b
    z1 = a0.dot(W1) + b1
    
    # Put it through the first activation function
    a1 = np.tanh(z1)
    
    # Second linear step
    z2 = a1.dot(W2) + b2
    
    # Second activation function
    a2 = np.tanh(z2)
    
    #Third linear step
    z3 = a2.dot(W3) + b3
    
    #For the Third linear activation function we use the softmax function, either the sigmoid of softmax should be used for the last layer
    a3 = softmax(z3)
    
    #Store all results in these values
    cache = {'a0':a0,'z1':z1,'a1':a1,'z2':z2,'a2':a2,'a3':a3,'z3':z3}
    return cache

# This is the BACKWARD PROPAGATION function
def backward_prop(model,cache,y):

    # Load parameters from model
    W1, b1, W2, b2, W3, b3 = model['W1'], model['b1'], model['W2'], model['b2'],model['W3'],model['b3']
    # Load forward propagation results
    a0,a1, a2,a3 = cache['a0'],cache['a1'],cache['a2'],cache['a3']
    
    # Get number of samples
    m = y.shape[0]
    
    # Calculate loss derivative with respect to output
    dz3 = loss_derivative(y=y,y_hat=a3)

    # Calculate loss derivative with respect to second layer weights
    dW3 = 1/m*(a2.T).dot(dz3) #dW2 = 1/m*(a1.T).dot(dz2) 
    
    # Calculate loss derivative with respect to second layer bias
    db3 = 1/m*np.sum(dz3, axis=0)
    
    # Calculate loss derivative with respect to first layer
    dz2 = np.multiply(dz3.dot(W3.T) ,tanh_derivative(a2))
    
    # Calculate loss derivative with respect to first layer weights
    dW2 = 1/m*np.dot(a1.T, dz2)
    
    # Calculate loss derivative with respect to first layer bias
    db2 = 1/m*np.sum(dz2, axis=0)
    
    dz1 = np.multiply(dz2.dot(W2.T),tanh_derivative(a1))
    
    dW1 = 1/m*np.dot(a0.T,dz1)
    
    db1 = 1/m*np.sum(dz1,axis=0)
    
    # Store gradients
    grads = {'dW3':dW3, 'db3':db3, 'dW2':dW2,'db2':db2,'dW1':dW1,'db1':db1}
    return grads

#TRAINING PHASE
def initialize_parameters(input_dim,l1_dim, l2_dim, output_dim):
    # First layer weights
    W1 = 2 *np.random.randn(input_dim, l1_dim) - 1
    
    # First layer bias
    b1 = np.zeros((1, l1_dim))
    
    # Second layer weights
    W2 = 2 * np.random.randn(l1_dim, l2_dim) - 1
    
    # Second layer bias
    b2 = np.zeros((1, l2_dim))
    W3 = 2 * np.random.rand(l2_dim, output_dim) - 1
    b3 = np.zeros((1,output_dim))
    
    
    # Package and return model
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2,'W3':W3,'b3':b3}
    return model

def update_parameters(model,grads,learning_rate):
    # Load parameters
    W1, b1, W2, b2,b3,W3 = model['W1'], model['b1'], model['W2'], model['b2'],model['b3'],model["W3"]
    
    # Update parameters
    W1 -= learning_rate * grads['dW1']
    b1 -= learning_rate * grads['db1']
    W2 -= learning_rate * grads['dW2']
    b2 -= learning_rate * grads['db2']
    W3 -= learning_rate * grads['dW3']
    b3 -= learning_rate * grads['db3']
    
    # load parameters into running lists
#     w00s.append(W1[0][0]) # modifies global list
#     w01s.append(W1[0][1]) # modifies global list
#     w02s.append(W1[0][2]) # modifies global list
#     w03s.append(W1[0][3]) # modifies global list
#     w04s.append(W1[0][4]) # modifies global list
    
#     w10s.append(W1[1][0]) # modifies global list
#     w11s.append(W1[1][1]) # modifies global list
#     w12s.append(W1[1][2]) # modifies global list
#     w13s.append(W1[1][3]) # modifies global list
#     w14s.append(W1[1][4]) # modifies global list
    
#     b0s.append(b1[0][0]) # modifies global list
#     b1s.append(b1[0][1]) # modifies global list
#     b2s.append(b1[0][2]) # modifies global list
#     b3s.append(b1[0][3]) # modifies global list
#     b4s.append(b1[0][4]) # modifies global list

    # Store and return parameters
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3':W3,'b3':b3}
    return model
def predict(model, x):
    # Do forward pass
    c = forward_prop(model,x)
    #get y_hat
    y_hat = c['a3']
    # plotArr.append([x, y_hat]) #added to make plot
    return y_hat
def calc_accuracy(model,x,y):
    # Get total number of examples
    m = y.shape[0]
    # Do a prediction with the model
    pred = predict(model,x)
    # Ensure prediction and truth vector y have the same shape
    pred = pred.reshape(y.shape)
    # Calculate the number of wrong examples
    error = np.sum(np.abs(pred-y))
    # Calculate accuracy
    return (m - error)/m * 100
def train(model,X_,y_,learning_rate, epochs=2001, print_loss=False):
    # Gradient descent. Loop over epochs
    for i in range(0, epochs):

        # Forward propagation
        cache = forward_prop(model,X_)
        #a1, probs = cache['a1'],cache['a2']
        # Backpropagation
        
        grads = backward_prop(model,cache,y_)
        # Gradient descent parameter update
        # Assign new parameters to the model
        model = update_parameters(model=model,grads=grads,learning_rate=learning_rate)
        # it is at this point in the training that the weights get added to the lists
    
        a3 = cache['a3']
        thisLoss = mse_loss(y_,a3) # set loss function here
#         losses.append(thisLoss) # modifies global list
        y_hat = predict(model,X_) # getting rid of this because it's wrong
        y_true = y_.argmax(axis=1)
        accur = accuracy_score(a3,train_labels)
#         train_accuracies.append(accur) # modifies global list
        
    # test accuracy
#         if i % 50 == 0:
#             placeholderVar = accuracy_score(a3, train_labels)
#             test_accuracy = accuracyOfModel(model, test_data, test_labels)
# #             test_accuracies.append(test_accuracy) # modifies global list
#             test_num.append(i)
#         #Printing loss & accuracy every 100 iterations
        if print_loss and i % 300==0:
            print('Loss after iteration',i,':',thisLoss)
            print('Train Accuracy after iteration',i,':',accur*100,'%')
            # print('Test Accuracy after iteration',i,':',test_accuracy*100,'%')
    return model

# TESTING PHASE
# test the accuracy of any model
def accuracyOfModel(_model, _testData, _testLabels):
    y_pred = predict(_model,_testData) # make predictions on test data
    y_true = _testLabels # get usable info from labels
    return accuracy_score(y_pred, y_true)

def accuracy_score(_outputNodes, _labels):
    for i in range(len(_outputNodes)-1):
        if _outputNodes[i][0]>.5:
            _outputNodes[i]=[1,0]
        else:
            _outputNodes[i]=[0,1]
    numWrong = np.count_nonzero(np.subtract(_outputNodes,_labels))/2
    return (len(_outputNodes)-numWrong)/len(_outputNodes)

# %%
# declare global list
accuracies = []
for i in range (1, 7):
    for j in range (1, 7):
        learnRate = 0.02 # set learning rate here
        np.random.seed(0)
        # This is what we return at the end
        model = initialize_parameters(2, i, j, 2)
        model = train(model,train_data,train_labels,learning_rate=learnRate,epochs=901,print_loss=True) # original learning rate is 0.01
        accuracies.append([i, j, accuracyOfModel(model, test_data, test_labels)])
# Out:
# Loss after iteration 0 : 0.5107894410139484
# Train Accuracy after iteration 0 : 50.517053930368384 %
# Loss after iteration 300 : 0.5001650535464061
# Train Accuracy after iteration 300 : 49.78635179894314 %
# Loss after iteration 600 : 0.5001258396845615
# Train Accuracy after iteration 600 : 49.80405046648631 %
# Loss after iteration 900 : 0.5000955423884395
# Train Accuracy after iteration 900 : 49.82680589618467 %
# Loss after iteration 0 : 0.6360231954260281
# Train Accuracy after iteration 0 : 50.517053930368384 %
# Loss after iteration 300 : 0.4998600873640585
# Train Accuracy after iteration 300 : 49.705443604460065 %
# Loss after iteration 600 : 0.49955012287536205
# Train Accuracy after iteration 600 : 49.756011226011985 %
# Loss after iteration 900 : 0.49935144888561306
# Train Accuracy after iteration 900 : 49.78888018002073 %
# Loss after iteration 0 : 0.6126370922807138
# Train Accuracy after iteration 0 : 49.48041768855402 %
# Loss after iteration 300 : 0.5027044191968005
# Train Accuracy after iteration 300 : 49.7484260827792 %
# Loss after iteration 600 : 0.5024860171001675
# Train Accuracy after iteration 600 : 49.81416399079669 %
# Loss after iteration 900 : 0.5022625302421255
# Train Accuracy after iteration 900 : 49.82680589618467 %
# Loss after iteration 0 : 0.740744895390401
# Train Accuracy after iteration 0 : 49.48041768855402 %
# Loss after iteration 300 : 0.5031193145466738
# Train Accuracy after iteration 300 : 49.85461808803823 %
# Loss after iteration 600 : 0.5028829485539148
# Train Accuracy after iteration 600 : 49.86220323127102 %
# Loss after iteration 900 : 0.502653442518435
# Train Accuracy after iteration 900 : 49.88748704204698 %
# Loss after iteration 0 : 0.5203276143143601
# Train Accuracy after iteration 0 : 50.517053930368384 %
# Loss after iteration 300 : 0.5005353783831229
# Train Accuracy after iteration 300 : 49.75095446385679 %
# Loss after iteration 600 : 0.5003155830539068
# Train Accuracy after iteration 600 : 49.72819903415843 %
# Loss after iteration 900 : 0.5001562904748359
# Train Accuracy after iteration 900 : 50.084700766099466 %
# Loss after iteration 0 : 0.5086562884193963
# Train Accuracy after iteration 0 : 50.517053930368384 %
# Loss after iteration 300 : 0.5002864200760542
# Train Accuracy after iteration 300 : 49.78888018002073 %
# Loss after iteration 600 : 0.500145863568818
# Train Accuracy after iteration 600 : 49.86220323127102 %
# Loss after iteration 900 : 0.5000345531323184
# Train Accuracy after iteration 900 : 50.16308057950495 %
# Loss after iteration 0 : 0.5084289202606553
# Train Accuracy after iteration 0 : 44.36297438749968 %
# Loss after iteration 300 : 0.504587712476575
# Train Accuracy after iteration 300 : 47.065813759449824 %
# Loss after iteration 600 : 0.5040584540586479
# Train Accuracy after iteration 600 : 40.96988698136583 %
# Loss after iteration 900 : 0.5036102534908261
# Train Accuracy after iteration 900 : 36.76771763040125 %
# Loss after iteration 0 : 0.5443138038491294
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.4998225357238065
# Train Accuracy after iteration 300 : 50.41086192510935 %
# Loss after iteration 600 : 0.49982080396236217
# Train Accuracy after iteration 600 : 50.40580516295417 %
# Loss after iteration 900 : 0.4998190703147326
# Train Accuracy after iteration 900 : 50.408333544031755 %
# Loss after iteration 0 : 0.6287769481919127
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.49954559111065944
# Train Accuracy after iteration 300 : 50.691512224722516 %
# Loss after iteration 600 : 0.49950894078493585
# Train Accuracy after iteration 600 : 50.76736365705039 %
# Loss after iteration 900 : 0.49947338357714005
# Train Accuracy after iteration 900 : 50.85585699476625 %
# Loss after iteration 0 : 0.6047987330828315
# Train Accuracy after iteration 0 : 49.991150666228414 %
# Loss after iteration 300 : 0.5030597384407488
# Train Accuracy after iteration 300 : 45.690374453237595 %
# Loss after iteration 600 : 0.5026512672046298
# Train Accuracy after iteration 600 : 45.91792875022123 %
# Loss after iteration 900 : 0.5023479084609538
# Train Accuracy after iteration 900 : 46.49945639806832 %
# Loss after iteration 0 : 0.7448845160192671
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.500284504785215
# Train Accuracy after iteration 300 : 49.59672321812344 %
# Loss after iteration 600 : 0.5002141468844636
# Train Accuracy after iteration 600 : 49.56638264519228 %
# Loss after iteration 900 : 0.500150833284406
# Train Accuracy after iteration 900 : 49.58913807489065 %
# Loss after iteration 0 : 0.730413273788836
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.49872259365367033
# Train Accuracy after iteration 300 : 52.08970696063311 %
# Loss after iteration 600 : 0.4984898055605929
# Train Accuracy after iteration 600 : 53.10358777274911 %
# Loss after iteration 900 : 0.4982739079886631
# Train Accuracy after iteration 900 : 53.77613713938965 %
# Loss after iteration 0 : 0.5131068275736255
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.5002792473328053
# Train Accuracy after iteration 300 : 48.817981846223866 %
# Loss after iteration 600 : 0.5002373640770938
# Train Accuracy after iteration 600 : 49.03289423781953 %
# Loss after iteration 900 : 0.5002060272444563
# Train Accuracy after iteration 900 : 48.92417385148289 %
# Loss after iteration 0 : 0.5071734679854468
# Train Accuracy after iteration 0 : 49.996207428383606 %
# Loss after iteration 300 : 0.50005510047918
# Train Accuracy after iteration 300 : 50.345124017091855 %
# Loss after iteration 600 : 0.5000332398937192
# Train Accuracy after iteration 600 : 50.307198300927915 %
# Loss after iteration 900 : 0.500011967655661
# Train Accuracy after iteration 900 : 50.75219337058482 %
# Loss after iteration 0 : 0.5078274293494164
# Train Accuracy after iteration 0 : 50.092285909332254 %
# Loss after iteration 300 : 0.5011639229992425
# Train Accuracy after iteration 300 : 50.29202801446234 %
# Loss after iteration 600 : 0.5002770601001882
# Train Accuracy after iteration 600 : 50.32489696847109 %
# Loss after iteration 900 : 0.500002117928913
# Train Accuracy after iteration 900 : 50.41086192510935 %
# Loss after iteration 0 : 0.7449594013847055
# Train Accuracy after iteration 0 : 51.24775606179364 %
# Loss after iteration 300 : 0.5029020789498574
# Train Accuracy after iteration 300 : 50.16560896058254 %
# Loss after iteration 600 : 0.5001877561774787
# Train Accuracy after iteration 600 : 50.65864327071377 %
# Loss after iteration 900 : 0.4994798925851818
# Train Accuracy after iteration 900 : 50.67128517610174 %
# Loss after iteration 0 : 0.5696607263924955
# Train Accuracy after iteration 0 : 49.84703294480544 %
# Loss after iteration 300 : 0.5011053086303985
# Train Accuracy after iteration 300 : 49.515815023640364 %
# Loss after iteration 600 : 0.5008789917483939
# Train Accuracy after iteration 600 : 49.57396778842507 %
# Loss after iteration 900 : 0.5006863320693863
# Train Accuracy after iteration 900 : 49.616950266744205 %
# Loss after iteration 0 : 0.5256363006849752
# Train Accuracy after iteration 0 : 50.420975449419736 %
# Loss after iteration 300 : 0.5007352877500648
# Train Accuracy after iteration 300 : 50.46142954666127 %
# Loss after iteration 600 : 0.49921299312880957
# Train Accuracy after iteration 600 : 50.55750802760992 %
# Loss after iteration 900 : 0.49879214696984636
# Train Accuracy after iteration 900 : 50.774948800283184 %
# Loss after iteration 0 : 0.5040034641764642
# Train Accuracy after iteration 0 : 48.49940583044676 %
# Loss after iteration 300 : 0.502224573211902
# Train Accuracy after iteration 300 : 48.064524285100255 %
# Loss after iteration 600 : 0.5015770568633604
# Train Accuracy after iteration 600 : 47.768703699021515 %
# Loss after iteration 900 : 0.5011999214355327
# Train Accuracy after iteration 900 : 47.51080882910672 %
# Loss after iteration 0 : 0.5371695410022637
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.500296900995036
# Train Accuracy after iteration 300 : 50.14032514980657 %
# Loss after iteration 600 : 0.500238795727574
# Train Accuracy after iteration 600 : 50.152967055194566 %
# Loss after iteration 900 : 0.5001954922986755
# Train Accuracy after iteration 900 : 50.12262648226341 %
# Loss after iteration 0 : 0.784608676341634
# Train Accuracy after iteration 0 : 50.0012641905388 %
# Loss after iteration 300 : 0.49377324670707357
# Train Accuracy after iteration 300 : 66.3674749058178 %
# Loss after iteration 600 : 0.492955989972309
# Train Accuracy after iteration 600 : 69.52289449065762 %
# Loss after iteration 900 : 0.4920580004536146
# Train Accuracy after iteration 900 : 70.1802735708326 %
# Loss after iteration 0 : 0.5064122139411507
# Train Accuracy after iteration 0 : 50.01137771484918 %
# Loss after iteration 300 : 0.5005108291352471
# Train Accuracy after iteration 300 : 47.92293494475487 %
# Loss after iteration 600 : 0.4996929129739368
# Train Accuracy after iteration 600 : 47.72319283962479 %
# Loss after iteration 900 : 0.4990990826403176
# Train Accuracy after iteration 900 : 48.45642335212763 %
# Loss after iteration 0 : 0.5051010953420706
# Train Accuracy after iteration 0 : 50.375464590023014 %
# Loss after iteration 300 : 0.4939745662740688
# Train Accuracy after iteration 300 : 52.782483375894415 %
# Loss after iteration 600 : 0.4921228591736549
# Train Accuracy after iteration 600 : 58.6230436651412 %
# Loss after iteration 900 : 0.4906090215784044
# Train Accuracy after iteration 900 : 68.87057217263785 %
# Loss after iteration 0 : 0.5821353749100026
# Train Accuracy after iteration 0 : 49.70291522338247 %
# Loss after iteration 300 : 0.5017508734993975
# Train Accuracy after iteration 300 : 48.656165457257714 %
# Loss after iteration 600 : 0.49984995697704493
# Train Accuracy after iteration 600 : 49.12644433769058 %
# Loss after iteration 900 : 0.49871775698186904
# Train Accuracy after iteration 900 : 49.546155596571516 %
# Loss after iteration 0 : 0.5064782200936099
# Train Accuracy after iteration 0 : 48.23898257945437 %
# Loss after iteration 300 : 0.5016468240090762
# Train Accuracy after iteration 300 : 48.972213091957215 %
# Loss after iteration 600 : 0.5004134478599309
# Train Accuracy after iteration 600 : 49.16437005385452 %
# Loss after iteration 900 : 0.4997391024544654
# Train Accuracy after iteration 900 : 51.267983110414406 %
# Loss after iteration 0 : 0.7260640819041082
# Train Accuracy after iteration 0 : 50.517053930368384 %
# Loss after iteration 300 : 0.5004432922559853
# Train Accuracy after iteration 300 : 50.45637278450607 %
# Loss after iteration 600 : 0.49923731397719695
# Train Accuracy after iteration 600 : 50.58784860054107 %
# Loss after iteration 900 : 0.49871156535441846
# Train Accuracy after iteration 900 : 50.706682511188085 %
# Loss after iteration 0 : 0.7276544566872097
# Train Accuracy after iteration 0 : 49.48547445070921 %
# Loss after iteration 300 : 0.5006853384561545
# Train Accuracy after iteration 300 : 50.26421582260878 %
# Loss after iteration 600 : 0.5000853098363454
# Train Accuracy after iteration 600 : 50.25663067937599 %
# Loss after iteration 900 : 0.49968853078960795
# Train Accuracy after iteration 900 : 50.15043867411696 %
# Loss after iteration 0 : 0.6996301170060221
# Train Accuracy after iteration 0 : 50.034133144547546 %
# Loss after iteration 300 : 0.5024519785514299
# Train Accuracy after iteration 300 : 43.45781396172031 %
# Loss after iteration 600 : 0.5010407484406043
# Train Accuracy after iteration 600 : 43.31116785921974 %
# Loss after iteration 900 : 0.49995750520242094
# Train Accuracy after iteration 900 : 43.025460797451395 %
# Loss after iteration 0 : 0.7419369971701677
# Train Accuracy after iteration 0 : 50.719324416576065 %
# Loss after iteration 300 : 0.46482919529838623
# Train Accuracy after iteration 300 : 67.03496751030316 %
# Loss after iteration 600 : 0.4367806991287798
# Train Accuracy after iteration 600 : 84.5111375186468 %
# Loss after iteration 900 : 0.40590465634946266
# Train Accuracy after iteration 900 : 98.08095876210461 %
# Loss after iteration 0 : 0.7646301025864777
# Train Accuracy after iteration 0 : 49.96333847437486 %
# Loss after iteration 300 : 0.44149768495030034
# Train Accuracy after iteration 300 : 73.93997623321788 %
# Loss after iteration 600 : 0.4106902233952292
# Train Accuracy after iteration 600 : 92.20500113777148 %
# Loss after iteration 900 : 0.447965354617332
# Train Accuracy after iteration 900 : 56.40059669793431 %
# Loss after iteration 0 : 0.6057488633288723
# Train Accuracy after iteration 0 : 50.5119971682132 %
# Loss after iteration 300 : 0.49999325877174045
# Train Accuracy after iteration 300 : 49.53857045333873 %
# Loss after iteration 600 : 0.49963828940839966
# Train Accuracy after iteration 600 : 49.53604207226113 %
# Loss after iteration 900 : 0.4994024110271633
# Train Accuracy after iteration 900 : 49.616950266744205 %
# Loss after iteration 0 : 0.5732205220086931
# Train Accuracy after iteration 0 : 51.27809663472479 %
# Loss after iteration 300 : 0.5008102266827346
# Train Accuracy after iteration 300 : 51.283153396879975 %
# Loss after iteration 600 : 0.49867852135570845
# Train Accuracy after iteration 600 : 51.66999570175217 %
# Loss after iteration 900 : 0.4978053037700703
# Train Accuracy after iteration 900 : 51.826755328563124 %
# Loss after iteration 0 : 0.5389473283357261
# Train Accuracy after iteration 0 : 50.42856059265253 %
# Loss after iteration 300 : 0.49864466092207643
# Train Accuracy after iteration 300 : 49.877373517736594 %
# Loss after iteration 600 : 0.498161242241798
# Train Accuracy after iteration 600 : 50.61313241131703 %
# Loss after iteration 900 : 0.49793110916189387
# Train Accuracy after iteration 900 : 50.694040605800105 %
# Loss after iteration 0 : 0.515096987417103
# Train Accuracy after iteration 0 : 50.57773507623069 %
# Loss after iteration 300 : 0.4995419704662459
# Train Accuracy after iteration 300 : 50.39822001972137 %
# Loss after iteration 600 : 0.4980063728240906
# Train Accuracy after iteration 600 : 51.0808829106723 %
# Loss after iteration 900 : 0.49654688667171487
# Train Accuracy after iteration 900 : 52.39311268994463 %
# Loss after iteration 0 : 0.5214106184265698
# Train Accuracy after iteration 0 : 47.25291395919193 %
# Loss after iteration 300 : 0.5000670709294689
# Train Accuracy after iteration 300 : 45.78898131526384 %
# Loss after iteration 600 : 0.4983916620988176
# Train Accuracy after iteration 600 : 45.67267578569442 %
# Loss after iteration 900 : 0.4976609059541128
# Train Accuracy after iteration 900 : 46.68655659781042 %
# Loss after iteration 0 : 0.5735229842777354
# Train Accuracy after iteration 0 : 50.51452554929079 %
# Loss after iteration 300 : 0.46383784861698313
# Train Accuracy after iteration 300 : 75.77052413339739 %
# Loss after iteration 600 : 0.4380644235678388
# Train Accuracy after iteration 600 : 84.34679274860308 %
# Loss after iteration 900 : 0.3972928165468613
# Train Accuracy after iteration 900 : 97.01398194735911 %

# %%
accuracies = np.array(accuracies)

# %%
print(accuracies[:,2])
# Out:
# [0.49801522 0.4978888  0.50160552 0.50168137 0.5014791  0.50218705
#  0.36573032 0.50292028 0.50752193 0.46332583 0.49973452 0.53667417
#  0.48767414 0.50489242 0.50807818 0.50911481 0.49925413 0.50984804
#  0.47867311 0.50018963 0.70152461 0.48595484 0.68731511 0.4941468
#  0.51343835 0.50676342 0.50084701 0.43139238 0.98098657 0.50256631
#  0.49667518 0.51877323 0.50618189 0.52484134 0.46721954 0.96869864]

# %%
vb:>¬
